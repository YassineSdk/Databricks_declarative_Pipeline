# %%
import dlt
@dlt.table(name="01_bronze.Real_estate_rabat",comment="raw data readings")
def raw_rabat_data():
  return (
    spark.readStream\
         .format("delta")\
         .load("/Volumes/real_estate_management/00_landing/streaming_data/RE_Rabat/")
  )


@dlt.table(name="01_bronze.Real_estate_tanger",comment="raw data readings")
def raw_tanger_data():
  return (
    spark.readStream \
         .format("delta") \
         .load("/Volumes/real_estate_management/00_landing/streaming_data/RE_tanger/")
  )

@dlt.table(name="01_bronze.Real_estate_casablanca",comment="raw data readings")
def raw_casablanca_data():
  return (
    spark.readStream \
         .format("delta")\
         .load("/Volumes/real_estate_management/00_landing/streaming_data/RE_casablanca/")
  )
